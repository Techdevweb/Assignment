# %%
ims={'Lays':{'name':'Lays','qty':13,'category':'snacks','price':10,'discount':'5%'},
    'Kitkat':{'name':'Kitkat','qty':24,'category':'chocolate','price':10,'discount':'4%'},
    'Maggie':{'name':'Maggie','qty':53,'category':'snacks','price':20,'discount':'4%'},
    'Fanta':{'name':'Fanta','qty':29,'category':'drinks','price':30,'discount':'6%'},
    'Kurkure':{'name':'Kurkure','qty':51,'category':'snacks','price':60,'discount':'10%'},
     'Mangobite':{'name':'Mangobite','qty':103,'category':'chocolate','price':1,'discount':'0%'},
     'Foog':{'name':'Foog','qty':80,'category':'deo','price':30,'discount':'4%'},
     'Football':{'name':'Football','qty':44,'category':'toys','price':140,'discount':'10%'},
     '5-star':{'name':'5-star','qty':60,'category':'chocolate','price':10,'discount':'2%'},
     'teddy bear':{'name':'teddy bear','qty':33,'category':'toys','price':120,'discount':'8%'},
     'jam':{'name':'jam','qty':500,'category':'food','price':60,'discount':'5%'},
    'Foodles':{'name':'Foodles','qty':24,'category':'snacks','price':10,'discount':'0%'},
    'Maggie':{'name':'Maggie','qty':53,'category':'snacks','price':20,'discount':'4%'},
    'ThumbsUp':{'name':'ThumbsUp','qty':29,'category':'drinks','price':20,'discount':'3%'},
    'Chiwda':{'name':'Chiwda','qty':21,'category':'snacks','price':60,'discount':'10%'},
     'Choco eclare':{'name':'Choco eclare','qty':133,'category':'chocolate','price':1,'discount':'0%'},
     'Axe':{'name':'Axe','qty':10,'category':'deo','price':25,'discount':'3%'},
     'Playing cars':{'name':'Playing cars','qty':144,'category':'toys','price':50,'discount':'10%'},
     'Barone':{'name':'Barone','qty':60,'category':'chocolate','price':10,'discount':'0%'},
     'Dool':{'name':'dool','qty':317,'category':'toys','price':250,'discount':'8%'},
    'Toast':{'name':'Toast','qty':53,'category':'snacks','price':40,'discount':'5%'},
    'Peark':{'name':'peark','qty':66,'category':'chocolate','price':20,'discount':'2%'},
    'Cornato':{'name':'Cornato','qty':53,'category':'snacks','price':20,'discount':'2%'},
    '7Up':{'name':'7Up','qty':49,'category':'drinks','price':30,'discount':'6%'},
    'Candy':{'name':'Candy','qty':57,'category':'snacks','price':20,'discount':'0%'},
     'Hajmola':{'name':'Hajmola','qty':113,'category':'chocolate','price':3,'discount':'0%'},
     'KacchaMangoBite':{'name':'KacchaMangoBite','qty':800,'category':'chocolate','price':1,'discount':'0%'},
     'Playing sword':{'name':'Playing sword','qty':74,'category':'toys','price':10,'discount':'0%'},
     'DairyMilk':{'name':'DairyMilk','qty':61,'category':'chocolate','price':10,'discount':'0%'},
     'Toy gun':{'name':'Toy gun','qty':44,'category':'toys','price':120,'discount':'8%'}
    }

# %%
ims
# Out:
# {'Lays': {'name': 'Lays',
#   'qty': 13,
#   'category': 'snacks',
#   'price': 10,
#   'discount': '5%'},
#  'Kitkat': {'name': 'Kitkat',
#   'qty': 24,
#   'category': 'chocolate',
#   'price': 10,
#   'discount': '4%'},
#  'Maggie': {'name': 'Maggie',
#   'qty': 53,
#   'category': 'snacks',
#   'price': 20,
#   'discount': '4%'},
#  'Fanta': {'name': 'Fanta',
#   'qty': 29,
#   'category': 'drinks',
#   'price': 30,
#   'discount': '6%'},
#  'Kurkure': {'name': 'Kurkure',
#   'qty': 51,
#   'category': 'snacks',
#   'price': 60,
#   'discount': '10%'},
#  'Mangobite': {'name': 'Mangobite',
#   'qty': 103,
#   'category': 'chocolate',
#   'price': 1,
#   'discount': '0%'},
#  'Foog': {'name': 'Foog',
#   'qty': 80,
#   'category': 'deo',
#   'price': 30,
#   'discount': '4%'},
#  'Football': {'name': 'Football',
#   'qty': 44,
#   'category': 'toys',
#   'price': 140,
#   'discount': '10%'},
#  '5-star': {'name': '5-star',
#   'qty': 60,
#   'category': 'chocolate',
# ...

# %%
import json

# %%
js=json.dumps(ims)
js
# Out:
# '{"Lays": {"name": "Lays", "qty": 13, "category": "snacks", "price": 10, "discount": "5%"}, "Kitkat": {"name": "Kitkat", "qty": 24, "category": "chocolate", "price": 10, "discount": "4%"}, "Maggie": {"name": "Maggie", "qty": 53, "category": "snacks", "price": 20, "discount": "4%"}, "Fanta": {"name": "Fanta", "qty": 29, "category": "drinks", "price": 30, "discount": "6%"}, "Kurkure": {"name": "Kurkure", "qty": 51, "category": "snacks", "price": 60, "discount": "10%"}, "Mangobite": {"name": "Mangobite", "qty": 103, "category": "chocolate", "price": 1, "discount": "0%"}, "Foog": {"name": "Foog", "qty": 80, "category": "deo", "price": 30, "discount": "4%"}, "Football": {"name": "Football", "qty": 44, "category": "toys", "price": 140, "discount": "10%"}, "5-star": {"name": "5-star", "qty": 60, "category": "chocolate", "price": 10, "discount": "2%"}, "teddy bear": {"name": "teddy bear", "qty": 33, "category": "toys", "price": 120, "discount": "8%"}, "jam": {"name": "jam", "qty": 500, "cate
# ...

# %%
fd=open('IMS.json','w')
fd.write(js)
fd.close()

# %%
fd=open('IMS.json','r')
txt=fd.read()
fd.close()

# %%
txt
# Out:
# '{"Lays": {"name": "Lays", "qty": 13, "category": "snacks", "price": 10, "discount": "5%"}, "Kitkat": {"name": "Kitkat", "qty": 24, "category": "chocolate", "price": 10, "discount": "4%"}, "Maggie": {"name": "Maggie", "qty": 53, "category": "snacks", "price": 20, "discount": "4%"}, "Fanta": {"name": "Fanta", "qty": 29, "category": "drinks", "price": 30, "discount": "6%"}, "Kurkure": {"name": "Kurkure", "qty": 51, "category": "snacks", "price": 60, "discount": "10%"}, "Mangobite": {"name": "Mangobite", "qty": 103, "category": "chocolate", "price": 1, "discount": "0%"}, "Foog": {"name": "Foog", "qty": 80, "category": "deo", "price": 30, "discount": "4%"}, "Football": {"name": "Football", "qty": 44, "category": "toys", "price": 140, "discount": "10%"}, "5-star": {"name": "5-star", "qty": 60, "category": "chocolate", "price": 10, "discount": "2%"}, "teddy bear": {"name": "teddy bear", "qty": 33, "category": "toys", "price": 120, "discount": "8%"}, "jam": {"name": "jam", "qty": 500, "cate
# ...

# %%
record=json.loads(txt)

# %%
record
# Out:
# {'Lays': {'name': 'Lays',
#   'qty': 13,
#   'category': 'snacks',
#   'price': 10,
#   'discount': '5%'},
#  'Kitkat': {'name': 'Kitkat',
#   'qty': 24,
#   'category': 'chocolate',
#   'price': 10,
#   'discount': '4%'},
#  'Maggie': {'name': 'Maggie',
#   'qty': 53,
#   'category': 'snacks',
#   'price': 20,
#   'discount': '4%'},
#  'Fanta': {'name': 'Fanta',
#   'qty': 29,
#   'category': 'drinks',
#   'price': 30,
#   'discount': '6%'},
#  'Kurkure': {'name': 'Kurkure',
#   'qty': 51,
#   'category': 'snacks',
#   'price': 60,
#   'discount': '10%'},
#  'Mangobite': {'name': 'Mangobite',
#   'qty': 103,
#   'category': 'chocolate',
#   'price': 1,
#   'discount': '0%'},
#  'Foog': {'name': 'Foog',
#   'qty': 80,
#   'category': 'deo',
#   'price': 30,
#   'discount': '4%'},
#  'Football': {'name': 'Football',
#   'qty': 44,
#   'category': 'toys',
#   'price': 140,
#   'discount': '10%'},
#  '5-star': {'name': '5-star',
#   'qty': 60,
#   'category': 'chocolate',
# ...

# %%
str=''
while(str!='exit'):
    print('Hello and welcome!!!! to our store')
    print('Please tell us what would you like to purchase:')
    pro=input('Enter your choice:')
    if pro in record:
        qty=input(int('How much quantity do you want:'))
        if record[pro][qty]>=qty:
            record[pro][qty]=record[pro][qty]-qty
            print('Your total amount is ',record[pro][qty]*record[pro][price])
            print('Thanks for purchasing!!! Do cisit again')
            str=str(inputt('Type exit to exit'))
        else:
            print("Sorry we don't have that much qty available")
            str='exit'
# Out:
# Hello and welcome!!!! to our store
# Please tell us what would you like to purchase:
# Enter your choice:Hajmola
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-98ad89253f4d> in <module>
#       5     pro=input('Enter your choice:')
#       6     if pro in record:
# ----> 7         qty=input(int('How much quantity do you want:'))
#       8         if record[pro][qty]>=qty:
#       9             record[pro][qty]=record[pro][qty]-qty
#
# ValueError: invalid literal for int() with base 10: 'How much quantity do you want:'
